# %% [markdown]
# # Mining the Social Web
#
# ## Mining GitHub
#
# This Jupyter Notebook provides an interactive way to follow along with and explore the examples from the video series. The intent behind this notebook is to reinforce the concepts in a fun, convenient, and effective way.

# %% [markdown]
# ## Programmatically obtaining a personal API access token for accessing GitHub's API

# %%
import requests
import json

username = '' # Your GitHub username
password = '' # Your GitHub password

# Note that credentials will be transmitted over a secure SSL connection
url = 'https://api.github.com/authorizations'
note = 'Mining the Social Web - Mining Github'
post_data = {'scopes':['repo'],'note': note }

response = requests.post(
    url,
    auth = (username, password),
    data = json.dumps(post_data),
    )   

print("API response:", response.text)
print()
print("Your OAuth token is", response.json()['token'])

# Go to https://github.com/settings/tokens to revoke this token

# %% [markdown]
# ## Making direct HTTP requests to GitHub's API

# %%
import json
import requests

# An unauthenticated request that doesn't contain an ?access_token=xxx query string
url = "https://api.github.com/repos/ptwobrussell/Mining-the-Social-Web/stargazers"
response = requests.get(url)

# Display one stargazer
print(json.dumps(response.json()[0], indent=1))
print()

# Display headers
for (k,v) in response.headers.items():
    print(k, "=>", v)

# %% [markdown]
# ## Using PyGithub to query for stargazers of a particular repository

# %%
from github import Github # pip install pygithub

# Specify your own access token here

ACCESS_TOKEN = 'faeb0c6594b27ac8b8e6265fd7bda0e23ebdeb51'

# Specify a username and repository of interest for that user.

USER = 'ptwobrussell'
REPO = 'Mining-the-Social-Web'
#REPO = 'Mining-the-Social-Web-2nd-Edition'

client = Github(ACCESS_TOKEN, per_page=100)
user = client.get_user(USER)
repo = user.get_repo(REPO)

# Get a list of people who have bookmarked the repo.
# Since you'll get a lazy iterator back, you have to traverse
# it if you want to get the total number of stargazers.

stargazers = [ s for s in repo.get_stargazers() ]
print("Number of stargazers", len(stargazers))
# Out:
# Number of stargazers 1175

# %% [markdown]
# ## Constructing a trivial property graph

# %%
import networkx as nx # pip install networkx

# Create a directed graph

g = nx.DiGraph()

# Add an edge to the directed graph from X to Y

g.add_edge('X', 'Y')

# Print some statistics about the graph

print(nx.info(g))
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 2
# Number of edges: 1
# Average in degree:   0.5000
# Average out degree:   0.5000

# %%
# Get the nodes and edges from the graph

print("Nodes:", g.nodes())
print("Edges:", g.edges())
print()

# Get node properties

print("X props:", g.node['X'])
print("Y props:", g.node['Y'])
print()

# Get edge properties

print("X=>Y props:", g['X']['Y'])
print()
# Out:
# Nodes: ['X', 'Y']
# Edges: [('X', 'Y')]
#
# X props: {}
# Y props: {}
#
# X=>Y props: {}

# %%
# Update a node property

g.node['X'].update({'prop1' : 'value1'})
print("X props:", g.node['X'])
print()

# Update an edge property

g['X']['Y'].update({'label' : 'label1'})
print("X=>Y props:", g['X']['Y'])
# Out:
# X props: {'prop1': 'value1'}
#
# X=>Y props: {'label': 'label1'}

# %% [markdown]
# ## Constructing an ego graph of a repository and its stargazers

# %%
# Expand the initial graph with (interest) edges pointing each direction for 
# additional people interested. Take care to ensure that user and repo nodes 
# do not collide by appending their type.

g = nx.DiGraph()
g.add_node(repo.name + '(repo)', type='repo', lang=repo.language, owner=user.login)

for sg in stargazers:
    g.add_node(sg.login + '(user)', type='user')
    g.add_edge(sg.login + '(user)', repo.name + '(repo)', type='gazes')

# %% [markdown]
# ## Introducing some handy graph operations
#
# Poke around in the current graph to get a better feel for how NetworkX works.

# %%
print(nx.info(g))
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 1176
# Number of edges: 1175
# Average in degree:   0.9991
# Average out degree:   0.9991

# %%
print(g.node['Mining-the-Social-Web(repo)'])
# Out:
# {'type': 'repo', 'lang': 'JavaScript', 'owner': 'ptwobrussell'}

# %%
print(g.node['ptwobrussell(user)'])

print(g['ptwobrussell(user)']['Mining-the-Social-Web(repo)'])
# Out:
# {'type': 'user'}
# {'type': 'gazes'}

# %%
print(g['ptwobrussell(user)'])
print(g['Mining-the-Social-Web(repo)'])
# Out:
# {'Mining-the-Social-Web(repo)': {'type': 'gazes'}}
# {}

# %%
print(g.in_edges(['ptwobrussell(user)']))
print(g.out_edges(['ptwobrussell(user)']))
# Out:
# []
# [('ptwobrussell(user)', 'Mining-the-Social-Web(repo)')]

# %%
print(g.in_edges(['Mining-the-Social-Web(repo)']))
print(g.out_edges(['Mining-the-Social-Web(repo)']))
# Out:
# [('rdempsey(user)', 'Mining-the-Social-Web(repo)'), ('frac(user)', 'Mining-the-Social-Web(repo)'), ('prb(user)', 'Mining-the-Social-Web(repo)'), ('mcroydon(user)', 'Mining-the-Social-Web(repo)'), ('batasrki(user)', 'Mining-the-Social-Web(repo)'), ('twleung(user)', 'Mining-the-Social-Web(repo)'), ('kevinchiu(user)', 'Mining-the-Social-Web(repo)'), ('nikolay(user)', 'Mining-the-Social-Web(repo)'), ('tswicegood(user)', 'Mining-the-Social-Web(repo)'), ('ngpestelos(user)', 'Mining-the-Social-Web(repo)'), ('darron(user)', 'Mining-the-Social-Web(repo)'), ('brunojm(user)', 'Mining-the-Social-Web(repo)'), ('rgaidot(user)', 'Mining-the-Social-Web(repo)'), ('openweb(user)', 'Mining-the-Social-Web(repo)'), ('shanlalit(user)', 'Mining-the-Social-Web(repo)'), ('hoffmann(user)', 'Mining-the-Social-Web(repo)'), ('nacht(user)', 'Mining-the-Social-Web(repo)'), ('hectoregm(user)', 'Mining-the-Social-Web(repo)'), ('tzuryby(user)', 'Mining-the-Social-Web(repo)'), ('marksands(user)', 'Mining-the-Social-Web(repo)'), ('wbzyl(user)', 'Mining-the-Social-Web(repo)'), ('sou(user)', 'Mining-the-Social-Web(repo)'), ('magnum(user)', 'Mining-the-Social-Web(repo)'), ('suzuki(user)', 'Mining-the-Social-Web(repo)'), ('tertsch(user)', 'Mining-the-Social-Web(repo)'), ('ymirpl(user)', 'Mining-the-Social-Web(repo)'), ('sebasmagri(user)', 'Mining-the-Social-Web(repo)'), ('galvez(user)', 'Mining-the-Social-Web(repo)'), ('paulbersch(user)', 'Mining-the-Social-Web(repo)'), ('georgebellos(user)', 'Mining-the-Social-Web(repo)'), ('acadopia(user)', 'Mining-the-Social-Web(repo)'), ('ggtr1138(user)', 'Mining-the-Social-Web(repo)'), ('program247365(user)', 'Mining-the-Social-Web(repo)'), ('edwelker(user)', 'Mining-the-Social-Web(repo)'), ('hammer(user)', 'Mining-the-Social-Web(repo)'), ('jengdal(user)', 'Mining-the-Social-Web(repo)'), ('brimbrom(user)', 'Mining-the-Social-Web(repo)'), ('gar(user)', 'Mining-the-Social-Web(repo)'), ('willi(user)', 'Mining-the-Social-Web(repo)'), ('gregmoreno(user)', 'Mining-the-Social-Web(repo)'), ('rays(user)', 'Mining-the-Social-Web(repo)'), ('rayleyva(user)', 'Mining-the-Social-Web(repo)'), ('paxan(user)', 'Mining-the-Social-Web(repo)'), ('eughenes(user)', 'Mining-the-Social-Web(repo)'), ('barce(user)', 'Mining-the-Social-Web(repo)'), ('abuiles(user)', 'Mining-the-Social-Web(repo)'), ('carhartl(user)', 'Mining-the-Social-Web(repo)'), ('jexchan(user)', 'Mining-the-Social-Web(repo)'), ('yasu00000(user)', 'Mining-the-Social-Web(repo)'), ('lsinger(user)', 'Mining-the-Social-Web(repo)'), ('yy(user)', 'Mining-the-Social-Web(repo)'), ('daemianmack(user)', 'Mining-the-Social-Web(repo)'), ('ricardoalmeida(user)', 'Mining-the-Social-Web(repo)'), ('gerad(user)', 'Mining-the-Social-Web(repo)'), ('amitagrawal(user)', 'Mining-the-Social-Web(repo)'), ('swinton(user)', 'Mining-the-Social-Web(repo)'), ('polonia(user)', 'Mining-the-Social-Web(repo)'), ('fozbaca(user)', 'Mining-the-Social-Web(repo)'), ('nborwankar(user)', 'Mining-the-Social-Web(repo)'), ('macdet(user)', 'Mining-the-Social-Web(repo)'), ('Smerity(user)', 'Mining-the-Social-Web(repo)'), ('joepestro(user)', 'Mining-the-Social-Web(repo)'), ('phauly(user)', 'Mining-the-Social-Web(repo)'), ('shamiksharma(user)', 'Mining-the-Social-Web(repo)'), ('lg2046(user)', 'Mining-the-Social-Web(repo)'), ('omg(user)', 'Mining-the-Social-Web(repo)'), ('lzell(user)', 'Mining-the-Social-Web(repo)'), ('eduardocereto(user)', 'Mining-the-Social-Web(repo)'), ('kshimo69(user)', 'Mining-the-Social-Web(repo)'), ('natorro(user)', 'Mining-the-Social-Web(repo)'), ('abecciu(user)', 'Mining-the-Social-Web(repo)'), ('CaptSolo(user)', 'Mining-the-Social-Web(repo)'), ('clyfe(user)', 'Mining-the-Social-Web(repo)'), ('mahmoudimus(user)', 'Mining-the-Social-Web(repo)'), ('mznmel(user)', 'Mining-the-Social-Web(repo)'), ('Kilian(user)', 'Mining-the-Social-Web(repo)'), ('stonegao(user)', 'Mining-the-Social-Web(repo)'), ('pcdinh(user)', 'Mining-the-Social-Web(repo)'), ('jacktang(user)', 'Mining-the-Social-Web(repo)'), ('Almad(user)', 'M ...
# []

# %% [markdown]
# ## Calculating degree, betweenness, and closeness centrality measures on the Krackhardt kite graph

# %%
from operator import itemgetter
from IPython.display import HTML
from IPython.core.display import display
import networkx as nx
display(HTML('<img src="kite-graph.png" width="400px">'))

# The classic Krackhardt kite graph
kkg = nx.generators.small.krackhardt_kite_graph()

print("Degree Centrality")
print(sorted(nx.degree_centrality(kkg).items(), 
             key=itemgetter(1), reverse=True))
print()

print("Betweenness Centrality")
print(sorted(nx.betweenness_centrality(kkg).items(), 
             key=itemgetter(1), reverse=True))
print()

print("Closeness Centrality")
print(sorted(nx.closeness_centrality(kkg).items(), 
             key=itemgetter(1), reverse=True))
# Out:
# <img src="kite-graph.png" width="400px">
# Degree Centrality
# [(3, 0.6666666666666666), (5, 0.5555555555555556), (6, 0.5555555555555556), (0, 0.4444444444444444), (1, 0.4444444444444444), (2, 0.3333333333333333), (4, 0.3333333333333333), (7, 0.3333333333333333), (8, 0.2222222222222222), (9, 0.1111111111111111)]
#
# Betweenness Centrality
# [(7, 0.38888888888888884), (5, 0.23148148148148148), (6, 0.23148148148148148), (8, 0.2222222222222222), (3, 0.10185185185185183), (0, 0.023148148148148143), (1, 0.023148148148148143), (2, 0.0), (4, 0.0), (9, 0.0)]
#
# Closeness Centrality
# [(5, 0.6428571428571429), (6, 0.6428571428571429), (3, 0.6), (7, 0.6), (0, 0.5294117647058824), (1, 0.5294117647058824), (2, 0.5), (4, 0.5), (8, 0.42857142857142855), (9, 0.3103448275862069)]

# %% [markdown]
# ## Adding additional interest edges to the graph through the inclusion of "follows" edges

# %%
# Add (social) edges from the stargazers' followers. This can take a while 
# because of all of the potential API calls to GitHub. The approximate number
# of requests for followers for each iteration of this loop can be calculated as
# math.ceil(sg.get_followers() / 100.0) per the API returning up to 100 items
# at a time.

import sys

for i, sg in enumerate(stargazers):
    
    # Add "follows" edges between stargazers in the graph if any relationships exist
    try:
        for follower in sg.get_followers()[:100]:
            if follower.login + '(user)' in g:
                g.add_edge(follower.login + '(user)', sg.login + '(user)', 
                           type='follows')
    except Exception as e: #ssl.SSLError
        print("Encountered an error fetching followers for", sg.login, \
              "Skipping.", file=sys.stderr)
        print(e, file=sys.stderr)

    print("Processed", i+1, " stargazers. Num nodes/edges in graph", \
          g.number_of_nodes(), "/", g.number_of_edges())
    print("Rate limit remaining", client.rate_limiting)
# Out:
# Processed 1  stargazers. Num nodes/edges in graph 1176 / 1178
# Rate limit remaining (4522, 5000)
# Processed 2  stargazers. Num nodes/edges in graph 1176 / 1181
# Rate limit remaining (4521, 5000)
# Processed 3  stargazers. Num nodes/edges in graph 1176 / 1183
# Rate limit remaining (4520, 5000)
# Processed 4  stargazers. Num nodes/edges in graph 1176 / 1187
# Rate limit remaining (4519, 5000)
# Processed 5  stargazers. Num nodes/edges in graph 1176 / 1188
# Rate limit remaining (4518, 5000)
# Processed 6  stargazers. Num nodes/edges in graph 1176 / 1190
# Rate limit remaining (4517, 5000)
# Processed 7  stargazers. Num nodes/edges in graph 1176 / 1191
# Rate limit remaining (4516, 5000)
# Processed 8  stargazers. Num nodes/edges in graph 1176 / 1193
# Rate limit remaining (4515, 5000)
# Processed 9  stargazers. Num nodes/edges in graph 1176 / 1196
# Rate limit remaining (4514, 5000)
# Processed 10  stargazers. Num nodes/edges in graph 1176 / 1199
# Rate limit remaining (4513, 5000)
# Processed 11  stargazers. Num nodes/edges in graph 1176 / 1201
# Rate limit remaining (4512, 5000)
# Processed 12  stargazers. Num nodes/edges in graph 1176 / 1204
# Rate limit remaining (4511, 5000)
# Processed 13  stargazers. Num nodes/edges in graph 1176 / 1207
# Rate limit remaining (4510, 5000)
# Processed 14  stargazers. Num nodes/edges in graph 1176 / 1209
# Rate limit remaining (4509, 5000)
# Processed 15  stargazers. Num nodes/edges in graph 1176 / 1211
# Rate limit remaining (4508, 5000)
# Processed 16  stargazers. Num nodes/edges in graph 1176 / 1216
# Rate limit remaining (4507, 5000)
# Processed 17  stargazers. Num nodes/edges in graph 1176 / 1217
# Rate limit remaining (4506, 5000)
# Processed 18  stargazers. Num nodes/edges in graph 1176 / 1220
# Rate limit remaining (4505, 5000)
# Processed 19  stargazers. Num nodes/edges in graph 1176 / 1225
# Rate limit remaining (4504, 5000)
# Processed 20  stargazers. Num nodes/edges in graph 1176 / 1226
# Rate limit remaining (4503, 5000)
# Processed 21  stargazers. Num nodes/edges in graph 1176 / 1227
# Rate limit remaining (4502, 5000)
# Processed 22  stargazers. Num nodes/edges in graph 1176 / 1228
# Rate limit remaining (4501, 5000)
# Processed 23  stargazers. Num nodes/edges in graph 1176 / 1229
# Rate limit remaining (4500, 5000)
# Processed 24  stargazers. Num nodes/edges in graph 1176 / 1231
# Rate limit remaining (4499, 5000)
# Processed 25  stargazers. Num nodes/edges in graph 1176 / 1232
# Rate limit remaining (4498, 5000)
# Processed 26  stargazers. Num nodes/edges in graph 1176 / 1233
# Rate limit remaining (4497, 5000)
# Processed 27  stargazers. Num nodes/edges in graph 1176 / 1237
# Rate limit remaining (4496, 5000)
# Processed 28  stargazers. Num nodes/edges in graph 1176 / 1239
# Rate limit remaining (4495, 5000)
# Processed 29  stargazers. Num nodes/edges in graph 1176 / 1240
# Rate limit remaining (4494, 5000)
# Processed 30  stargazers. Num nodes/edges in graph 1176 / 1242
# Rate limit remaining (4493, 5000)
# Processed 31  stargazers. Num nodes/edges in graph 1176 / 1244
# Rate limit remaining (4492, 5000)
# Processed 32  stargazers. Num nodes/edges in graph 1176 / 1245
# Rate limit remaining (4491, 5000)
# Processed 33  stargazers. Num nodes/edges in graph 1176 / 1247
# Rate limit remaining (4490, 5000)
# Processed 34  stargazers. Num nodes/edges in graph 1176 / 1248
# Rate limit remaining (4489, 5000)
# Processed 35  stargazers. Num nodes/edges in graph 1176 / 1256
# Rate limit remaining (4488, 5000)
# Processed 36  stargazers. Num nodes/edges in graph 1176 / 1257
# Rate limit remaining (4487, 5000)
# Processed 37  stargazers. Num nodes/edges in graph 1176 / 1259
# Rate limit remaining (4486, 5000)
# Processed 38  stargazers. Num nodes/edges in graph 1176 / 1260
# Rate limit remaining (4485, 5000)
# Processed 39  stargazers. Num nodes/edges in graph 1176 / 1262
# Rate limit remaining (4484, 5000)
# Processed 40  stargazers. Num nodes/edges in graph 1176 / 1265
# Rate limit remaining (4483, 5000)
# Processed 41  stargazers. Num nodes/edges in graph 1176 / 1266
# Rate limit remaining (4482, 5000)
# Processed 42  stargazers. Num nodes/edges in graph 1176 / 1268
# Rate limit remaining (4481, 5000)
# Processed 43  stargazers. Num nodes/edges in graph 1176 / 1270
# Rate limit remaining (4480, 5000)
# Processed 44  stargazers. Num nodes/edges in graph 1176 / 1271
# Rate limit remaining (4479, 5000)
# Processed 45  stargazers. Num nodes/edges in graph 1176 / 1274
# Rate limit remaining (4478, 5000)
# Processed 46  stargazers. Num nodes/edges in graph 1176 / 1275
# Rate limit remaining (4477, 5000)
# Processed 47  stargazers. Num nodes/edges in graph 1176 / 1275
# Rate limit remaining (4476, 5000)
# Processed 48  stargazers. Num nodes/edges in graph 1176 / 1277
# Rate limit remaining (4475, 5000)
# Processed 49  stargazers. Num nodes/edges in graph 1176 / 1278
# Rate limit remaining (4474, 5000)
# Processed 50  stargazers. Num nodes/edges in graph 1176 / 1279
# Rate limit remaining (4473, 5000)
# Processed 51  stargazers. Num nodes/edges in graph 1176 / 1280
# Rate limit remaining (4472, 5000)
# Processed 52  stargazers. Num nodes/edges in graph 1176 / 1282
# Rate limit remaining (4471, 5000)
# Processed 53  stargazers. Num nodes/edges in graph 1176 / 1283
# Rate limit remaining (4470, 5000)
# Processed 54  stargazers. Num nodes/edges in graph 1176 / 1286
# Rate limit remaining (4469, 5000)
# Processed 55  stargazers. Num nodes/edges in graph 1176 / 1287
# Rate limit remaining (4468, 5000)
# Processed 56  stargazers. Num nodes/edges in graph 1176 / 1289
# Rate limit remaining (4467, 5000)
# Processed 57  stargazers. Num nodes/edges in graph 1176 / 1290
# Rate limit remaining (4466, 5000)
# Processed 58  stargazers. Num nodes/edges in graph 1176 / 1291
# Rate limit remaining (4465, 5000)
# Processed 59  stargazers. Num nodes/edges in graph 1176 / 1294
# Rate limit remaining (4464, 5000)
# Processed 60  stargazers. Num nodes/edges in graph 1176 / 1295
# Rate limit remaining (4463, 5000)
# Processed 61  stargazers. Num nodes/edges in graph 1176 / 1301
# Rate limit remaining (4462, 5000)
# Processed 62  stargazers. Num nodes/edges in graph 1176 / 1302
# Rate limit remaining (4461, 5000)
# Processed 63  stargazers. Num nodes/edges in graph 1176 / 1305
# Rate limit remaining (4460, 5000)
# Processed 64  stargazers. Num nodes/edges in graph 1176 / 1306
# Rate limit remaining (4459, 5000)
# Processed 65  stargazers. Num nodes/edges in graph 1176 / 1307
# Rate limit remaining (4458, 5000)
# Processed 66  stargazers. Num nodes/edges in graph 1176 / 1308
# Rate limit remaining (4457, 5000)
# Processed 67  stargazers. Num nodes/edges in graph 1176 / 1309
# Rate limit remaining (4456, 5000)
# Processed 68  stargazers. Num nodes/edges in graph 1176 / 1310
# Rate limit remaining (4455, 5000)
# Processed 69  stargazers. Num nodes/edges in graph 1176 / 1311
# Rate limit remaining (4454, 5000)
# Processed 70  stargazers. Num nodes/edges in graph 1176 / 1313
# Rate limit remaining (4453, 5000)
# Processed 71  stargazers. Num nodes/edges in graph 1176 / 1318
# Rate limit remaining (4452, 5000)
# Processed 72  stargazers. Num nodes/edges in graph 1176 / 1320
# Rate limit remaining (4451, 5000)
# Processed 73  stargazers. Num nodes/edges in graph 1176 / 1322
# Rate limit remaining (4450, 5000)
# Processed 74  stargazers. Num nodes/edges in graph 1176 / 1324
# Rate limit remaining (4449, 5000)
# Processed 75  stargazers. Num nodes/edges in graph 1176 / 1326
# Rate limit remaining (4448, 5000)
# Processed 76  stargazers. Num nodes/edges in graph 1176 / 1330
# Rate limit remaining (4447, 5000)
# Processed 77  stargazers. Num nodes/edges in graph 1176 / 1331
# Rate limit remaining (4446, 5000)
# Processed 78  stargazers. Num nodes/edges in graph 1176 / 1332
# Rate limit remaining (4445, 5000)
# Processed 79  stargazers. Num nodes/edges in graph 1176 / 1333
# Rate limit remaining (4444, 5000)
# Processed 80  stargazers. Num nodes/edges in graph 1176 / 1334
# Rate limit remaining (4443, 5000)
# Processed 81  stargazers. Num nodes/edges in graph 1176 / 1336
# Rate limit remaining (4442, 5000)
# Processed 82  stargazers. Num nodes/edges in graph 1176 / 1338
# Rate limit remaining (4441, 5000)
# Processed 83  stargazers. Num nodes/edges in graph 1176 / 1342
# Rate limit remaining (4440, 5000)
# Processed 84  stargazers. Num nodes/edges in graph 1176 / 1344
# Rate limit remaining (4439, 5000)
# Processed 85  stargazers. Num nodes/edges in graph 1176 / 1345
# Rate limit remaining (4438, 5000)
# Processed 86  stargazers. Num nodes/edges in graph 1176 / 1345
# Rate limit remaining (4437, 5000)
# Processed 87  stargazers. Num nodes/edges in graph 1176 / 1348
# Rate limit remaining (4436, 5000)
# Processed 88  stargazers. Num nodes/edges in graph 1176 / 1350
# Rate limit remaining (4435, 5000)
# Processed 89  stargazers. Num nodes/edges in graph 1176 / 1351
# Rate limit remaining (4434, 5000)
# Processed 90  stargazers. Num nodes/edges in graph 1176 / 1356
# Rate limit remaining (4433, 5000)
# Processed 91  stargazers. Num nodes/edges in graph 1176 / 1357
# Rate limit remaining (4432, 5000)
# Processed 92  stargazers. Num nodes/edges in graph 1176 / 1361
# Rate limit remaining (4431, 5000)
# Processed 93  stargazers. Num nodes/edges in graph 1176 / 1362
# Rate limit remaining (4430, 5000)
# Processed 94  stargazers. Num nodes/edges in graph 1176 / 1363
# Rate limit remaining (4429, 5000)
# Processed 95  stargazers. Num nodes/edges in graph 1176 / 1367
# Rate limit remaining (4428, 5000)
# Processed 96  stargazers. Num nodes/edges in graph 1176 / 1368
# Rate limit remaining (4427, 5000)
# Processed 97  stargazers. Num nodes/edges in graph 1176 / 1369
# Rate limit remaining (4426, 5000)
# Processed 98  stargazers. Num nodes/edges in graph 1176 / 1371
# Rate limit remaining (4425, 5000)
# Processed 99  stargazers. Num nodes/edges in graph 1176 / 1374
# Rate limit remaining (4424, 5000)
# Processed 100  stargazers. Num nodes/edges in graph 1176 / 1375
# Rate limit remaining (4423, 5000)
# Processed 101  stargazers. Num nodes/edges in graph 1176 / 1376
# Rate limit remaining (4422, 5000)
# Processed 102  stargazers. Num nodes/edges in graph 1176 / 1377
# Rate limit remaining (4421, 5000)
# Processed 103  stargazers. Num nodes/edges in graph 1176 / 1378
# Rate limit remaining (4420, 5000)
# Processed 104  stargazers. Num nodes/edges in graph 1176 / 1381
# Rate limit remaining (4419, 5000)
# Processed 105  stargazers. Num nodes/edges in graph 1176 / 1382
# Rate limit remaining (4418, 5000)
# Processed 106  stargazers. Num nodes/edges in graph 1176 / 1383
# Rate limit remaining (4417, 5000)
# Processed 107  stargazers. Num nodes/edges in graph 1176 / 1384
# Rate limit remaining (4416, 5000)
# Processed 108  stargazers. Num nodes/edges in graph 1176 / 1385
# Rate limit remaining (4415, 5000)
# Processed 109  stargazers. Num nodes/edges in graph 1176 / 1386
# Rate limit remaining (4414, 5000)
# Processed 110  stargazers. Num nodes/edges in graph 1176 / 1387
# Rate limit remaining (4413, 5000)
# Processed 111  stargazers. Num nodes/edges in graph 1176 / 1390
# Rate limit remaining (4412, 5000)
# Processed 112  stargazers. Num nodes/edges in graph 1176 / 1392
# Rate limit remaining (4411, 5000)
# Processed 113  stargazers. Num nodes/edges in graph 1176 / 1396
# Rate limit remaining (4410, 5000)
# Processed 114  stargazers. Num nodes/edges in graph 1176 / 1397
# Rate limit remaining (4409, 5000)
# Processed 115  stargazers. Num nodes/edges in graph 1176 / 1405
# Rate limit remaining (4408, 5000)
# Processed 116  stargazers. Num nodes/edges in graph 1176 / 1406
# Rate limit remaining (4407, 5000)
# Processed 117  stargazers. Num nodes/edges in graph 1176 / 1407
# Rate limit remaining (4406, 5000)
# Processed 118  stargazers. Num nodes/edges in graph 1176 / 1408
# Rate limit remaining (4405, 5000)
# Processed 119  stargazers. Num nodes/edges in graph 1176 / 1413
# Rate limit remaining (4404, 5000)
# Processed 120  stargazers. Num nodes/edges in graph 1176 / 1413
# Rate limit remaining (4403, 5000)
# Processed 121  stargazers. Num nodes/edges in graph 1176 / 1416
# Rate limit remaining (4402, 5000)
# Processed 122  stargazers. Num nodes/edges in graph 1176 / 1417
# Rate limit remaining (4401, 5000)
# Processed 123  stargazers. Num nodes/edges in graph 1176 / 1418
# Rate limit remaining (4400, 5000)
# Processed 124  stargazers. Num nodes/edges in graph 1176 / 1419
# Rate limit remaining (4399, 5000)
# Processed 125  stargazers. Num nodes/edges in graph 1176 / 1420
# Rate limit remaining (4398, 5000)
# Processed 126  stargazers. Num nodes/edges in graph 1176 / 1421
# Rate limit remaining (4397, 5000)
# Processed 127  stargazers. Num nodes/edges in graph 1176 / 1422
# Rate limit remaining (4396, 5000)
# Processed 128  stargazers. Num nodes/edges in graph 1176 / 1422
# Rate limit remaining (4395, 5000)
# Processed 129  stargazers. Num nodes/edges in graph 1176 / 1424
# Rate limit remaining (4394, 5000)
# Processed 130  stargazers. Num nodes/edges in graph 1176 / 1424
# Rate limit remaining (4393, 5000)
# Processed 131  stargazers. Num nodes/edges in graph 1176 / 1426
# Rate limit remaining (4392, 5000)
# Processed 132  stargazers. Num nodes/edges in graph 1176 / 1426
# Rate limit remaining (4391, 5000)
# Processed 133  stargazers. Num nodes/edges in graph 1176 / 1427
# Rate limit remaining (4390, 5000)
# Processed 134  stargazers. Num nodes/edges in graph 1176 / 1428
# Rate limit remaining (4389, 5000)
# Processed 135  stargazers. Num nodes/edges in graph 1176 / 1429
# Rate limit remaining (4388, 5000)
# Processed 136  stargazers. Num nodes/edges in graph 1176 / 1429
# Rate limit remaining (4387, 5000)
# Processed 137  stargazers. Num nodes/edges in graph 1176 / 1430
# Rate limit remaining (4386, 5000)
# Processed 138  stargazers. Num nodes/edges in graph 1176 / 1430
# Rate limit remaining (4385, 5000)
# Processed 139  stargazers. Num nodes/edges in graph 1176 / 1431
# Rate limit remaining (4384, 5000)
# Processed 140  stargazers. Num nodes/edges in graph 1176 / 1435
# Rate limit remaining (4383, 5000)
# Processed 141  stargazers. Num nodes/edges in graph 1176 / 1435
# Rate limit remaining (4382, 5000)
# Processed 142  stargazers. Num nodes/edges in graph 1176 / 1437
# Rate limit remaining (4381, 5000)
# Processed 143  stargazers. Num nodes/edges in graph 1176 / 1437
# Rate limit remaining (4380, 5000)
# Processed 144  stargazers. Num nodes/edges in graph 1176 / 1437
# Rate limit remaining (4379, 5000)
# Processed 145  stargazers. Num nodes/edges in graph 1176 / 1437
# Rate limit remaining (4378, 5000)
# Processed 146  stargazers. Num nodes/edges in graph 1176 / 1438
# Rate limit remaining (4377, 5000)
# Processed 147  stargazers. Num nodes/edges in graph 1176 / 1439
# Rate limit remaining (4376, 5000)
# Processed 148  stargazers. Num nodes/edges in graph 1176 / 1441
# Rate limit remaining (4375, 5000)
# Processed 149  stargazers. Num nodes/edges in graph 1176 / 1443
# Rate limit remaining (4374, 5000)
# Processed 150  stargazers. Num nodes/edges in graph 1176 / 1487
# Rate limit remaining (4373, 5000)
# Processed 151  stargazers. Num nodes/edges in graph 1176 / 1489
# Rate limit remaining (4372, 5000)
# Processed 152  stargazers. Num nodes/edges in graph 1176 / 1490
# Rate limit remaining (4371, 5000)
# Processed 153  stargazers. Num nodes/edges in graph 1176 / 1491
# Rate limit remaining (4370, 5000)
# Processed 154  stargazers. Num nodes/edges in graph 1176 / 1494
# Rate limit remaining (4369, 5000)
# Processed 155  stargazers. Num nodes/edges in graph 1176 / 1494
# Rate limit remaining (4368, 5000)
# Processed 156  stargazers. Num nodes/edges in graph 1176 / 1494
# Rate limit remaining (4367, 5000)
# Processed 157  stargazers. Num nodes/edges in graph 1176 / 1494
# Rate limit remaining (4366, 5000)
# Processed 158  stargazers. Num nodes/edges in graph 1176 / 1496
# Rate limit remaining (4365, 5000)
# Processed 159  stargazers. Num nodes/edges in graph 1176 / 1498
# Rate limit remaining (4364, 5000)
# Processed 160  stargazers. Num nodes/edges in graph 1176 / 1499
# Rate limit remaining (4363, 5000)
# Processed 161  stargazers. Num nodes/edges in graph 1176 / 1499
# Rate limit remaining (4362, 5000)
# Processed 162  stargazers. Num nodes/edges in graph 1176 / 1499
# Rate limit remaining (4361, 5000)
# Processed 163  stargazers. Num nodes/edges in graph 1176 / 1502
# Rate limit remaining (4360, 5000)
# Processed 164  stargazers. Num nodes/edges in graph 1176 / 1505
# Rate limit remaining (4359, 5000)
# Processed 165  stargazers. Num nodes/edges in graph 1176 / 1506
# Rate limit remaining (4358, 5000)
# Processed 166  stargazers. Num nodes/edges in graph 1176 / 1506
# Rate limit remaining (4357, 5000)
# Processed 167  stargazers. Num nodes/edges in graph 1176 / 1506
# Rate limit remaining (4356, 5000)
# Processed 168  stargazers. Num nodes/edges in graph 1176 / 1509
# Rate limit remaining (4355, 5000)
# Processed 169  stargazers. Num nodes/edges in graph 1176 / 1512
# Rate limit remaining (4354, 5000)
# Processed 170  stargazers. Num nodes/edges in graph 1176 / 1512
# Rate limit remaining (4353, 5000)
# Processed 171  stargazers. Num nodes/edges in graph 1176 / 1513
# Rate limit remaining (4352, 5000)
# Processed 172  stargazers. Num nodes/edges in graph 1176 / 1515
# Rate limit remaining (4351, 5000)
# Processed 173  stargazers. Num nodes/edges in graph 1176 / 1516
# Rate limit remaining (4350, 5000)
# Processed 174  stargazers. Num nodes/edges in graph 1176 / 1519
# Rate limit remaining (4349, 5000)
# Processed 175  stargazers. Num nodes/edges in graph 1176 / 1519
# Rate limit remaining (4348, 5000)
# Processed 176  stargazers. Num nodes/edges in graph 1176 / 1519
# Rate limit remaining (4347, 5000)
# Processed 177  stargazers. Num nodes/edges in graph 1176 / 1521
# Rate limit remaining (4346, 5000)
# Processed 178  stargazers. Num nodes/edges in graph 1176 / 1523
# Rate limit remaining (4345, 5000)
# Processed 179  stargazers. Num nodes/edges in graph 1176 / 1525
# Rate limit remaining (4344, 5000)
# Processed 180  stargazers. Num nodes/edges in graph 1176 / 1525
# Rate limit remaining (4343, 5000)
# Processed 181  stargazers. Num nodes/edges in graph 1176 / 1532
# Rate limit remaining (4342, 5000)
# Processed 182  stargazers. Num nodes/edges in graph 1176 / 1536
# Rate limit remaining (4341, 5000)
# Processed 183  stargazers. Num nodes/edges in graph 1176 / 1536
# Rate limit remaining (4340, 5000)
# Processed 184  stargazers. Num nodes/edges in graph 1176 / 1537
# Rate limit remaining (4339, 5000)
# Processed 185  stargazers. Num nodes/edges in graph 1176 / 1540
# Rate limit remaining (4338, 5000)
# Processed 186  stargazers. Num nodes/edges in graph 1176 / 1540
# Rate limit remaining (4337, 5000)
# Processed 187  stargazers. Num nodes/edges in graph 1176 / 1540
# Rate limit remaining (4336, 5000)
# Processed 188  stargazers. Num nodes/edges in graph 1176 / 1540
# Rate limit remaining (4335, 5000)
# Processed 189  stargazers. Num nodes/edges in graph 1176 / 1541
# Rate limit remaining (4334, 5000)
# Processed 190  stargazers. Num nodes/edges in graph 1176 / 1548
# Rate limit remaining (4333, 5000)
# Processed 191  stargazers. Num nodes/edges in graph 1176 / 1549
# Rate limit remaining (4332, 5000)
# Processed 192  stargazers. Num nodes/edges in graph 1176 / 1549
# Rate limit remaining (4331, 5000)
# Processed 193  stargazers. Num nodes/edges in graph 1176 / 1550
# Rate limit remaining (4330, 5000)
# Processed 194  stargazers. Num nodes/edges in graph 1176 / 1550
# Rate limit remaining (4329, 5000)
# Processed 195  stargazers. Num nodes/edges in graph 1176 / 1550
# Rate limit remaining (4328, 5000)
# Processed 196  stargazers. Num nodes/edges in graph 1176 / 1551
# Rate limit remaining (4327, 5000)
# Processed 197  stargazers. Num nodes/edges in graph 1176 / 1552
# Rate limit remaining (4326, 5000)
# Processed 198  stargazers. Num nodes/edges in graph 1176 / 1552
# Rate limit remaining (4325, 5000)
# Processed 199  stargazers. Num nodes/edges in graph 1176 / 1553
# Rate limit remaining (4324, 5000)
# Processed 200  stargazers. Num nodes/edges in graph 1176 / 1554
# Rate limit remaining (4323, 5000)
# Processed 201  stargazers. Num nodes/edges in graph 1176 / 1558
# Rate limit remaining (4322, 5000)
# Processed 202  stargazers. Num nodes/edges in graph 1176 / 1558
# Rate limit remaining (4321, 5000)
# Processed 203  stargazers. Num nodes/edges in graph 1176 / 1559
# Rate limit remaining (4320, 5000)
# Processed 204  stargazers. Num nodes/edges in graph 1176 / 1560
# Rate limit remaining (4319, 5000)
# Processed 205  stargazers. Num nodes/edges in graph 1176 / 1561
# Rate limit remaining (4318, 5000)
# Processed 206  stargazers. Num nodes/edges in graph 1176 / 1562
# Rate limit remaining (4317, 5000)
# Processed 207  stargazers. Num nodes/edges in graph 1176 / 1563
# Rate limit remaining (4316, 5000)
# Processed 208  stargazers. Num nodes/edges in graph 1176 / 1563
# Rate limit remaining (4315, 5000)
# Processed 209  stargazers. Num nodes/edges in graph 1176 / 1563
# Rate limit remaining (4314, 5000)
# Processed 210  stargazers. Num nodes/edges in graph 1176 / 1564
# Rate limit remaining (4313, 5000)
# Processed 211  stargazers. Num nodes/edges in graph 1176 / 1565
# Rate limit remaining (4312, 5000)
# Processed 212  stargazers. Num nodes/edges in graph 1176 / 1569
# Rate limit remaining (4311, 5000)
# Processed 213  stargazers. Num nodes/edges in graph 1176 / 1571
# Rate limit remaining (4310, 5000)
# Processed 214  stargazers. Num nodes/edges in graph 1176 / 1572
# Rate limit remaining (4309, 5000)
# Processed 215  stargazers. Num nodes/edges in graph 1176 / 1574
# Rate limit remaining (4308, 5000)
# Processed 216  stargazers. Num nodes/edges in graph 1176 / 1576
# Rate limit remaining (4307, 5000)
# Processed 217  stargazers. Num nodes/edges in graph 1176 / 1576
# Rate limit remaining (4306, 5000)
# Processed 218  stargazers. Num nodes/edges in graph 1176 / 1576
# Rate limit remaining (4305, 5000)
# Processed 219  stargazers. Num nodes/edges in graph 1176 / 1577
# Rate limit remaining (4304, 5000)
# Processed 220  stargazers. Num nodes/edges in graph 1176 / 1578
# Rate limit remaining (4303, 5000)
# Processed 221  stargazers. Num nodes/edges in graph 1176 / 1579
# Rate limit remaining (4302, 5000)
# Processed 222  stargazers. Num nodes/edges in graph 1176 / 1579
# Rate limit remaining (4301, 5000)
# Processed 223  stargazers. Num nodes/edges in graph 1176 / 1581
# Rate limit remaining (4300, 5000)
# Processed 224  stargazers. Num nodes/edges in graph 1176 / 1584
# Rate limit remaining (4299, 5000)
# Processed 225  stargazers. Num nodes/edges in graph 1176 / 1584
# Rate limit remaining (4298, 5000)
# Processed 226  stargazers. Num nodes/edges in graph 1176 / 1584
# Rate limit remaining (4297, 5000)
# Processed 227  stargazers. Num nodes/edges in graph 1176 / 1586
# Rate limit remaining (4296, 5000)
# Processed 228  stargazers. Num nodes/edges in graph 1176 / 1586
# Rate limit remaining (4295, 5000)
# Processed 229  stargazers. Num nodes/edges in graph 1176 / 1588
# Rate limit remaining (4294, 5000)
# Processed 230  stargazers. Num nodes/edges in graph 1176 / 1590
# Rate limit remaining (4293, 5000)
# Processed 231  stargazers. Num nodes/edges in graph 1176 / 1590
# Rate limit remaining (4292, 5000)
# Processed 232  stargazers. Num nodes/edges in graph 1176 / 1590
# Rate limit remaining (4291, 5000)
# Processed 233  stargazers. Num nodes/edges in graph 1176 / 1591
# Rate limit remaining (4290, 5000)
# Processed 234  stargazers. Num nodes/edges in graph 1176 / 1596
# Rate limit remaining (4289, 5000)
# Processed 235  stargazers. Num nodes/edges in graph 1176 / 1598
# Rate limit remaining (4288, 5000)
# Processed 236  stargazers. Num nodes/edges in graph 1176 / 1600
# Rate limit remaining (4287, 5000)
# Processed 237  stargazers. Num nodes/edges in graph 1176 / 1601
# Rate limit remaining (4286, 5000)
# Processed 238  stargazers. Num nodes/edges in graph 1176 / 1602
# Rate limit remaining (4285, 5000)
# Processed 239  stargazers. Num nodes/edges in graph 1176 / 1602
# Rate limit remaining (4284, 5000)
# Processed 240  stargazers. Num nodes/edges in graph 1176 / 1603
# Rate limit remaining (4283, 5000)
# Processed 241  stargazers. Num nodes/edges in graph 1176 / 1604
# Rate limit remaining (4282, 5000)
# Processed 242  stargazers. Num nodes/edges in graph 1176 / 1604
# Rate limit remaining (4281, 5000)
# Processed 243  stargazers. Num nodes/edges in graph 1176 / 1605
# Rate limit remaining (4280, 5000)
# Processed 244  stargazers. Num nodes/edges in graph 1176 / 1605
# Rate limit remaining (4279, 5000)
# Processed 245  stargazers. Num nodes/edges in graph 1176 / 1606
# Rate limit remaining (4278, 5000)
# Processed 246  stargazers. Num nodes/edges in graph 1176 / 1610
# Rate limit remaining (4277, 5000)
# Processed 247  stargazers. Num nodes/edges in graph 1176 / 1611
# Rate limit remaining (4276, 5000)
# Processed 248  stargazers. Num nodes/edges in graph 1176 / 1612
# Rate limit remaining (4275, 5000)
# Processed 249  stargazers. Num nodes/edges in graph 1176 / 1614
# Rate limit remaining (4274, 5000)
# Processed 250  stargazers. Num nodes/edges in graph 1176 / 1614
# Rate limit remaining (4273, 5000)
# Processed 251  stargazers. Num nodes/edges in graph 1176 / 1614
# Rate limit remaining (4272, 5000)
# Processed 252  stargazers. Num nodes/edges in graph 1176 / 1615
# Rate limit remaining (4271, 5000)
# Processed 253  stargazers. Num nodes/edges in graph 1176 / 1631
# Rate limit remaining (4270, 5000)
# Processed 254  stargazers. Num nodes/edges in graph 1176 / 1633
# Rate limit remaining (4269, 5000)
# Processed 255  stargazers. Num nodes/edges in graph 1176 / 1634
# Rate limit remaining (4268, 5000)
# Processed 256  stargazers. Num nodes/edges in graph 1176 / 1634
# Rate limit remaining (4267, 5000)
# Processed 257  stargazers. Num nodes/edges in graph 1176 / 1635
# Rate limit remaining (4266, 5000)
# Processed 258  stargazers. Num nodes/edges in graph 1176 / 1635
# Rate limit remaining (4265, 5000)
# Processed 259  stargazers. Num nodes/edges in graph 1176 / 1636
# Rate limit remaining (4264, 5000)
# Processed 260  stargazers. Num nodes/edges in graph 1176 / 1637
# Rate limit remaining (4263, 5000)
# Processed 261  stargazers. Num nodes/edges in graph 1176 / 1638
# Rate limit remaining (4262, 5000)
# Processed 262  stargazers. Num nodes/edges in graph 1176 / 1638
# Rate limit remaining (4261, 5000)
# Processed 263  stargazers. Num nodes/edges in graph 1176 / 1638
# Rate limit remaining (4260, 5000)
# Processed 264  stargazers. Num nodes/edges in graph 1176 / 1640
# Rate limit remaining (4259, 5000)
# Processed 265  stargazers. Num nodes/edges in graph 1176 / 1640
# Rate limit remaining (4258, 5000)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-c13f8f58ea24> in <module>
#      11     # Add "follows" edges between stargazers in the graph if any relationships exist
#      12     try:
# ---> 13         for follower in sg.get_followers()[:100]:
#      14             if follower.login + '(user)' in g:
#      15                 g.add_edge(follower.login + '(user)', sg.login + '(user)',
#
# /usr/local/lib/python3.6/dist-packages/github/PaginatedList.py in __iter__(self)
#      89             while not self.__finished(index):
#      90                 if self.__list._isBiggerThan(index):
# ---> 91                     yield self.__list[index]
#      92                     index += self.__step
#      93                 else:
#
# /usr/local/lib/python3.6/dist-packages/github/PaginatedList.py in __getitem__(self, index)
#      53         assert isinstance(index, (int, slice))
#      54         if isinstance(index, int):
# ---> 55             self.__fetchToIndex(index)
#      56             return self.__elements[index]
#      57         else:
#
# /usr/local/lib/python3.6/dist-packages/github/PaginatedList.py in __fetchToIndex(self, index)
#      71     def __fetchToIndex(self, index):
#      72         while len(self.__elements) <= index and self._couldGrow():
# ---> 73             self._grow()
#      74
#      75     def _grow(self):
#
# /usr/local/lib/python3.6/dist-packages/github/PaginatedList.py in _grow(self)
#      74
#      75     def _grow(self):
# ---> 76         newElements = self._fetchNextPage()
#      77         self.__elements += newElements
#      78         return newElements
#
# /usr/local/lib/python3.6/dist-packages/github/PaginatedList.py in _fetchNextPage(self)
#     199             self.__nextUrl,
#     200             parameters=self.__nextParams,
# --> 201             headers=self.__headers
#     202         )
#     203         data = data if data else []
#
# /usr/local/lib/python3.6/dist-packages/github/Requester.py in requestJsonAndCheck(self, verb, url, parameters, headers, input)
#     273
#     274     def requestJsonAndCheck(self, verb, url, parameters=None, headers=None, input=None):
# --> 275         return self.__check(*self.requestJson(verb, url, parameters, headers, input, self.__customConnection(url)))
#     276
#     277     def requestMultipartAndCheck(self, verb, url, parameters=None, headers=None, input=None):
#
# /usr/local/lib/python3.6/dist-packages/github/Requester.py in requestJson(self, verb, url, parameters, headers, input, cnx)
#     333             return "application/json", json.dumps(input)
#     334
# --> 335         return self.__requestEncode(cnx, verb, url, parameters, headers, input, encode)
#     336
#     337     def requestMultipart(self, verb, url, parameters=None, headers=None, input=None, cnx=None):
#
# /usr/local/lib/python3.6/dist-packages/github/Requester.py in __requestEncode(self, cnx, verb, url, parameters, requestHeaders, input, encode)
#     386         self.NEW_DEBUG_FRAME(requestHeaders)
#     387
# --> 388         status, responseHeaders, output = self.__requestRaw(cnx, verb, url, requestHeaders, encoded_input)
#     389
#     390         if Consts.headerRateRemaining in responseHeaders and Consts.headerRateLimit in responseHeaders:
#
# /usr/local/lib/python3.6/dist-packages/github/Requester.py in __requestRaw(self, cnx, verb, url, requestHeaders, input)
#     410             requestHeaders
#     411         )
# --> 412         response = cnx.getresponse()
#     413
#     414         status = response.status
#
# /usr/local/lib/python3.6/dist-packages/github/Requester.py in getresponse(self)
#     112         verb = getattr(self.session, self.verb.lower())
#     113         url = "%s://%s:%s%s" % (self.protocol, self.host, self.port, self.url)
# --> 114         r = verb(url, headers=self.headers, data=self.input, timeout=self.timeout, verify=self.verify, allow_redirects=False)
#     115         return RequestsResponse(r)
#     116
#
# ~/.local/lib/python3.6/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     544
#     545         kwargs.setdefault('allow_redirects', True)
# --> 546         return self.request('GET', url, **kwargs)
#     547
#     548     def options(self, url, **kwargs):
#
# ~/.local/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/.local/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/.local/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /usr/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /usr/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /usr/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /usr/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1010                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#    1014             return socket.recv_into(self, buffer, nbytes, flags)
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     872             raise ValueError("Read on closed or unwrapped SSL socket.")
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#     876             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Exploring the updated graph's "follows" edges

# %%
from operator import itemgetter
from collections import Counter

# Let's see how many social edges we added since last time.
print(nx.info(g))
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 1176
# Number of edges: 1640
# Average in degree:   1.3946
# Average out degree:   1.3946

# %%
# The number of "follows" edges is the difference
print(len([e for e in g.edges(data=True) if e[2]['type'] == 'follows']))
# Out:
# 465

# %%
# The repository owner is possibly one of the more popular users in this graph.
print(len([e 
           for e in g.edges(data=True) 
               if e[2]['type'] == 'follows' and e[1] == 'ptwobrussell(user)']))
# Out:
# 44

# %%
# Let's examine the number of adjacent edges to each node
print(sorted([n for n in g.degree()], key=itemgetter(1), reverse=True)[:10])
# Out:
# [('Mining-the-Social-Web(repo)', 1175), ('angusshire(user)', 170), ('ptwobrussell(user)', 45), ('VagrantStory(user)', 36), ('trietptm(user)', 24), ('japerk(user)', 17), ('hammer(user)', 11), ('rohithadassanayake(user)', 11), ('gr33ndata(user)', 10), ('mcroydon(user)', 9)]

# %%
# Consider the ratio of incoming and outgoing edges for a couple of users with 
# high node degrees...

print(len(g.out_edges('mcanthony(user)')))
print(len(g.in_edges('mcanthony(user)')))
# Out:
# 8
# 0

# %%
# A user who is followed by many but does not follow back.

print(len(g.out_edges('ptwobrussell(user)')))
print(len(g.in_edges('ptwobrussell(user)')))
# Out:
# 1
# 44

# %%
c = Counter([e[1] for e in g.edges(data=True) if e[2]['type'] == 'follows'])
popular_users = [ (u, f) for (u, f) in c.most_common() if f > 1 ]
print("Number of popular users", len(popular_users))
print("Top 10 popular users:", popular_users[:10])
# Out:
# Number of popular users 103
# Top 10 popular users: [('ptwobrussell(user)', 44), ('japerk(user)', 16), ('napo(user)', 8), ('hammer(user)', 8), ('bcambel(user)', 7), ('gr33ndata(user)', 7), ('Smerity(user)', 6), ('abecciu(user)', 5), ('twidi(user)', 5), ('hoffmann(user)', 5)]

# %% [markdown]
# ## Snapshotting (pickling) the graph's state to disk

# %%
# Save your work by serializing out (pickling) the graph
nx.write_gpickle(g, "data/github.gpickle.1")

# How to restore the graph...
# import networkx as nx
#  g = nx.read_gpickle("data/github.gpickle.1")

# %% [markdown]
# ## Applying centrality measures to the interest graph

# %%
from operator import itemgetter

# Create a copy of the graph so that we can iteratively mutate the copy
# as needed for experimentation

h = g.copy()

# Remove the seed of the interest graph, which is a supernode, in order
# to get a better idea of the network dynamics

h.remove_node('Mining-the-Social-Web(repo)')

# Remove any other nodes that appear to be supernodes.
# Filter any other nodes that you can by threshold
# criteria or heuristics from inspection.

# Display the centrality measures for the top 10 nodes


dc = sorted(nx.degree_centrality(h).items(), 
            key=itemgetter(1), reverse=True)

print("Degree Centrality")
print(dc[:10])
print()

bc = sorted(nx.betweenness_centrality(h).items(), 
            key=itemgetter(1), reverse=True)

print("Betweenness Centrality")
print(bc[:10])
print()

print("Closeness Centrality")
cc = sorted(nx.closeness_centrality(h).items(), 
            key=itemgetter(1), reverse=True)
print(cc[:10])
# Out:
# Degree Centrality
# [('angusshire(user)', 0.14395229982964225), ('ptwobrussell(user)', 0.03747870528109029), ('VagrantStory(user)', 0.029812606473594547), ('trietptm(user)', 0.019591141396933562), ('japerk(user)', 0.013628620102214651), ('hammer(user)', 0.008517887563884156), ('rohithadassanayake(user)', 0.008517887563884156), ('gr33ndata(user)', 0.007666098807495741), ('mcroydon(user)', 0.0068143100511073255), ('abecciu(user)', 0.0068143100511073255)]
#
# Betweenness Centrality
# [('mcroydon(user)', 2.9893694633125698e-05), ('abecciu(user)', 2.5294664689567898e-05), ('tswicegood(user)', 2.444747496312304e-05), ('matagus(user)', 2.1663851576232794e-05), ('hammer(user)', 1.9243309500676056e-05), ('miku(user)', 1.5249415076007442e-05), ('kenneth-reitz(user)', 1.3676062726895563e-05), ('gr33ndata(user)', 1.0892439340005316e-05), ('stonegao(user)', 1.0166276717338295e-05), ('ngpestelos(user)', 9.167252987972152e-06)]
#
# Closeness Centrality
# [('ptwobrussell(user)', 0.04104619701372883), ('japerk(user)', 0.015241581789843778), ('miku(user)', 0.008835220629989645), ('hammer(user)', 0.008711475917608796), ('evandrix(user)', 0.007393999621427219), ('napo(user)', 0.0068143100511073255), ('hoffmann(user)', 0.006275423286861592), ('acdha(user)', 0.006272262660678334), ('gr33ndata(user)', 0.00596252129471891), ('bcambel(user)', 0.005749574105621806)]

# %% [markdown]
# ## Adding starred repositories to the graph

# %%
# Let's add each stargazer's additional starred repos and add edges 
# to find additional interests.

MAX_REPOS = 500

for i, sg in enumerate(stargazers):
    print(sg.login)
    try:
        for starred in sg.get_starred()[:MAX_REPOS]: # Slice to avoid supernodes
            g.add_node(starred.name + '(repo)', type='repo', lang=starred.language, \
                       owner=starred.owner.login)
            g.add_edge(sg.login + '(user)', starred.name + '(repo)', type='gazes')
    except Exception as e: #ssl.SSLError:
        print("Encountered an error fetching starred repos for", sg.login, "Skipping.")

    print("Processed", i+1, "stargazers' starred repos")
    print("Num nodes/edges in graph", g.number_of_nodes(), "/", g.number_of_edges())
    print("Rate limit", client.rate_limiting)
# Out:
# rdempsey
# Processed 1 stargazers' starred repos
# Num nodes/edges in graph 1674 / 2138
# Rate limit (4252, 5000)
# frac
# Processed 2 stargazers' starred repos
# Num nodes/edges in graph 1809 / 2277
# Rate limit (4250, 5000)
# prb
# Processed 3 stargazers' starred repos
# Num nodes/edges in graph 1987 / 2461
# Rate limit (4248, 5000)
# mcroydon
# Processed 4 stargazers' starred repos
# Num nodes/edges in graph 2475 / 2961
# Rate limit (4243, 5000)
# batasrki
# Processed 5 stargazers' starred repos
# Num nodes/edges in graph 2528 / 3019
# Rate limit (4242, 5000)
# twleung
# Processed 6 stargazers' starred repos
# Num nodes/edges in graph 2653 / 3151
# Rate limit (4240, 5000)
# kevinchiu
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-dbc3cbed0f10> in <module>
#       7     print(sg.login)
#       8     try:
# ----> 9         for starred in sg.get_starred()[:MAX_REPOS]: # Slice to avoid supernodes
#      10             g.add_node(starred.name + '(repo)', type='repo', lang=starred.language, \
#      11                        owner=starred.owner.login)
#
# /usr/local/lib/python3.6/dist-packages/github/PaginatedList.py in __iter__(self)
#      89             while not self.__finished(index):
#      90                 if self.__list._isBiggerThan(index):
# ---> 91                     yield self.__list[index]
#      92                     index += self.__step
#      93                 else:
#
# /usr/local/lib/python3.6/dist-packages/github/PaginatedList.py in __getitem__(self, index)
#      53         assert isinstance(index, (int, slice))
#      54         if isinstance(index, int):
# ---> 55             self.__fetchToIndex(index)
#      56             return self.__elements[index]
#      57         else:
#
# /usr/local/lib/python3.6/dist-packages/github/PaginatedList.py in __fetchToIndex(self, index)
#      71     def __fetchToIndex(self, index):
#      72         while len(self.__elements) <= index and self._couldGrow():
# ---> 73             self._grow()
#      74
#      75     def _grow(self):
#
# /usr/local/lib/python3.6/dist-packages/github/PaginatedList.py in _grow(self)
#      74
#      75     def _grow(self):
# ---> 76         newElements = self._fetchNextPage()
#      77         self.__elements += newElements
#      78         return newElements
#
# /usr/local/lib/python3.6/dist-packages/github/PaginatedList.py in _fetchNextPage(self)
#     199             self.__nextUrl,
#     200             parameters=self.__nextParams,
# --> 201             headers=self.__headers
#     202         )
#     203         data = data if data else []
#
# /usr/local/lib/python3.6/dist-packages/github/Requester.py in requestJsonAndCheck(self, verb, url, parameters, headers, input)
#     273
#     274     def requestJsonAndCheck(self, verb, url, parameters=None, headers=None, input=None):
# --> 275         return self.__check(*self.requestJson(verb, url, parameters, headers, input, self.__customConnection(url)))
#     276
#     277     def requestMultipartAndCheck(self, verb, url, parameters=None, headers=None, input=None):
#
# /usr/local/lib/python3.6/dist-packages/github/Requester.py in requestJson(self, verb, url, parameters, headers, input, cnx)
#     333             return "application/json", json.dumps(input)
#     334
# --> 335         return self.__requestEncode(cnx, verb, url, parameters, headers, input, encode)
#     336
#     337     def requestMultipart(self, verb, url, parameters=None, headers=None, input=None, cnx=None):
#
# /usr/local/lib/python3.6/dist-packages/github/Requester.py in __requestEncode(self, cnx, verb, url, parameters, requestHeaders, input, encode)
#     386         self.NEW_DEBUG_FRAME(requestHeaders)
#     387
# --> 388         status, responseHeaders, output = self.__requestRaw(cnx, verb, url, requestHeaders, encoded_input)
#     389
#     390         if Consts.headerRateRemaining in responseHeaders and Consts.headerRateLimit in responseHeaders:
#
# /usr/local/lib/python3.6/dist-packages/github/Requester.py in __requestRaw(self, cnx, verb, url, requestHeaders, input)
#     410             requestHeaders
#     411         )
# --> 412         response = cnx.getresponse()
#     413
#     414         status = response.status
#
# /usr/local/lib/python3.6/dist-packages/github/Requester.py in getresponse(self)
#     112         verb = getattr(self.session, self.verb.lower())
#     113         url = "%s://%s:%s%s" % (self.protocol, self.host, self.port, self.url)
# --> 114         r = verb(url, headers=self.headers, data=self.input, timeout=self.timeout, verify=self.verify, allow_redirects=False)
#     115         return RequestsResponse(r)
#     116
#
# ~/.local/lib/python3.6/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     544
#     545         kwargs.setdefault('allow_redirects', True)
# --> 546         return self.request('GET', url, **kwargs)
#     547
#     548     def options(self, url, **kwargs):
#
# ~/.local/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/.local/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/.local/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /usr/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /usr/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /usr/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /usr/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1010                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#    1014             return socket.recv_into(self, buffer, nbytes, flags)
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     872             raise ValueError("Read on closed or unwrapped SSL socket.")
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#     876             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# **NOTE: Given that the above example is potentially a very time-consuming example to run, be sure to snapshot your work**

# %%
# Save your work by serializing out another snapshot of the graph
nx.write_gpickle(g, "data/github.gpickle.2")

#import networkx as nx
# g = nx.read_gpickle("data/github.gpickle.2")

# %% [markdown]
# ## Exploring the graph after updates with additional starred repositories

# %%
# Poke around: how to get users/repos
from operator import itemgetter

print(nx.info(g))
print()

# Get a list of repositories from the graph.

repos = [n for n in g.nodes() if g.node[n]['type'] == 'repo']

# Most popular repos

print("Popular repositories")
print(sorted([(n,d) 
              for (n,d) in g.in_degree() 
                  if g.node[n]['type'] == 'repo'], \
             key=itemgetter(1), reverse=True)[:10])
print()

# Projects gazed at by a user

print("Respositories that ptwobrussell has bookmarked")
print([(n,g.node[n]['lang']) 
       for n in g['ptwobrussell(user)'] 
           if g['ptwobrussell(user)'][n]['type'] == 'gazes'])
print()

# Programming languages for each user

print("Programming languages ptwobrussell is interested in")
print(list(set([g.node[n]['lang'] 
                for n in g['ptwobrussell(user)'] 
                    if g['ptwobrussell(user)'][n]['type'] == 'gazes'])))
print()

# Find supernodes in the graph by approximating with a high number of 
# outgoing edges

print("Supernode candidates")
print(sorted([(n, len(g.out_edges(n))) 
              for n in g.nodes() 
                  if g.node[n]['type'] == 'user' and len(g.out_edges(n)) > 500], \
             key=itemgetter(1), reverse=True))
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 2740
# Number of edges: 3251
# Average in degree:   1.1865
# Average out degree:   1.1865
#
# Popular repositories
# [('Mining-the-Social-Web(repo)', 1175), ('models(repo)', 3), ('pybrain(repo)', 3), ('vowpal_wabbit(repo)', 3), ('colly(repo)', 3), ('matrixprofile-ts(repo)', 2), ('Horizon(repo)', 2), ('flair(repo)', 2), ('prophet(repo)', 2), ('Apriori(repo)', 2)]
#
# Respositories that ptwobrussell has bookmarked
# [('Mining-the-Social-Web(repo)', 'JavaScript')]
#
# Programming languages ptwobrussell is interested in
# ['JavaScript']
#
# Supernode candidates
# [('mcroydon(user)', 505)]

# %% [markdown]
# ## Updating the graph to include nodes for programming languages

# %%
# Iterate over all of the repos, and add edges for programming languages 
# for each person in the graph. We'll also add edges back to repos so that 
# we have a good point to "pivot" upon.

repos = [n 
         for n in g.nodes() 
             if g.node[n]['type'] == 'repo']

for repo in repos:
    lang = (g.node[repo]['lang'] or "") + "(lang)"
    
    stargazers = [u 
                  for (u, r, d) in g.in_edges(repo, data=True) 
                     if d['type'] == 'gazes'
                 ]
    
    for sg in stargazers:
        g.add_node(lang, type='lang')
        g.add_edge(sg, lang, type='programs')
        g.add_edge(lang, repo, type='implements')

# %% [markdown]
# ## Sample queries for the final graph

# %%
# Some stats

print(nx.info(g))
print()

# What languages exist in the graph?

print([n 
       for n in g.nodes() 
           if g.node[n]['type'] == 'lang'])
print()

# What languages do users program with?
print([n 
       for n in g['ptwobrussell(user)'] 
           if g['ptwobrussell(user)'][n]['type'] == 'programs'])

print()

# What is the most popular programming language?
print("Most popular languages")
print(sorted([(n, g.in_degree(n))
 for n in g.nodes() 
     if g.node[n]['type'] == 'lang'], key=itemgetter(1), reverse=True)[:10])
print()

# How many users program in a particular language?
python_programmers = [u 
                      for (u, l) in g.in_edges('Python(lang)') 
                          if g.node[u]['type'] == 'user']
print("Number of Python programmers:", len(python_programmers))
print()

javascript_programmers = [u for 
                          (u, l) in g.in_edges('JavaScript(lang)') 
                              if g.node[u]['type'] == 'user']
print("Number of JavaScript programmers:", len(javascript_programmers))
print()

# What users program in both Python and JavaScript?
print("Number of programmers who use JavaScript and Python")
print(len(set(python_programmers).intersection(set(javascript_programmers))))

# Programmers who use JavaScript but not Python
print("Number of programmers who use JavaScript but not Python")
print(len(set(javascript_programmers).difference(set(python_programmers))))

# Can you determine who is the most polyglot programmer?
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 2798
# Number of edges: 6145
# Average in degree:   2.1962
# Average out degree:   2.1962
#
# ['JavaScript(lang)', 'Ruby(lang)', 'Rust(lang)', 'Python(lang)', '(lang)', 'Dockerfile(lang)', 'Jupyter Notebook(lang)', 'Java(lang)', 'C(lang)', 'C++(lang)', 'HTML(lang)', 'TypeScript(lang)', 'Perl(lang)', 'Shell(lang)', 'Roff(lang)', 'Go(lang)', 'CSS(lang)', 'C#(lang)', 'XSLT(lang)', 'Scala(lang)', 'R(lang)', 'PHP(lang)', 'Erlang(lang)', 'Elixir(lang)', 'Matlab(lang)', 'TeX(lang)', 'VimL(lang)', 'CoffeeScript(lang)', 'Haskell(lang)', 'Clojure(lang)', 'Emacs Lisp(lang)', 'Groovy(lang)', 'OCaml(lang)', 'Swift(lang)', 'Verilog(lang)', 'HCL(lang)', 'Jsonnet(lang)', 'Objective-C(lang)', 'Makefile(lang)', 'PostScript(lang)', 'Arduino(lang)', 'Kotlin(lang)', 'Awk(lang)', 'Tcl(lang)', 'GLSL(lang)', 'Lua(lang)', 'COBOL(lang)', 'Batchfile(lang)', 'Visual Basic(lang)', 'Assembly(lang)', 'Cuda(lang)', 'Ada(lang)', 'Common Lisp(lang)', 'Vim script(lang)', 'D(lang)', 'PowerShell(lang)', 'Objective-C++(lang)', 'Dart(lang)']
#
# ['JavaScript(lang)']
#
# Most popular languages
# [('JavaScript(lang)', 1175), ('Ruby(lang)', 7), ('Python(lang)', 7), ('(lang)', 7), ('C(lang)', 7), ('Shell(lang)', 7), ('Java(lang)', 6), ('C++(lang)', 6), ('HTML(lang)', 6), ('Go(lang)', 6)]
#
# Number of Python programmers: 7
#
# Number of JavaScript programmers: 1175
#
# Number of programmers who use JavaScript and Python
# 7
# Number of programmers who use JavaScript but not Python
# 1168

# %% [markdown]
# **NOTE: Optionally, snapshot the final graph**

# %%
# Save your work by serializing out another snapshot of the graph
nx.write_gpickle(g, "data/github.gpickle.3")

#import networkx as nx
# g = nx.read_gpickle("data/github.gpickle.3")

# %% [markdown]
# ## Graph visualization of the social network for the original interest graph

# %%
print("Stats on the full graph")
print(nx.info(g))
print()

# Create a subgraph from a collection of nodes. In this case, the
# collection is all of the users in the original interest graph

mtsw_users = [n for n in g if g.node[n]['type'] == 'user']
h = g.subgraph(mtsw_users)

print("Stats on the extracted subgraph")
print(nx.info(h))
# Out:
# Stats on the full graph
# Name:
# Type: DiGraph
# Number of nodes: 2798
# Number of edges: 6145
# Average in degree:   2.1962
# Average out degree:   2.1962
#
# Stats on the extracted subgraph
# Name:
# Type: DiGraph
# Number of nodes: 1175
# Number of edges: 465
# Average in degree:   0.3957
# Average out degree:   0.3957

# %%
import os
import json
from IPython.display import IFrame
from IPython.core.display import display
from networkx.readwrite import json_graph

# Visualize the social network of all people from the original interest graph.
d = json_graph.node_link_data(h)
json.dump(d, open('force.json', 'w'))


# Jupyter Notebook can serve files and display them into
# inline frames. Prepend the path with the 'files' prefix.

# A D3 template for displaying the graph data.
viz_file = 'interest_graph.html'

# Display the D3 visualization.

display(IFrame(viz_file, '100%', '500px'))
# Out:
#         <iframe
#             width="100%"
#             height="500px"
#             src="interest_graph.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Using Matplotlib and NetworkX to create graph visualizations

# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline


fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(111)
labels = dict([(n, n.split('(user)')[0]) for n in h.nodes()])

nx.draw(h, pos=nx.spring_layout(h), 
        arrows=False, ax=ax, node_size=50,
        edge_color='#aaaaaa',
        alpha=0.8, labels=labels, font_size=8)
